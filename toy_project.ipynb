# %%
import pandas as pd 
data=pd.read_csv('online_news4semiconductor.csv')
# Out:
# C:\Users\LENOVO\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#                        @timestamp category  \
# 0       2019-09-26T05:09:04+00:00     news
# 1       2019-09-26T04:54:03+00:00     news
# 2       2019-09-26T04:48:02+00:00     news
# 3       2019-09-26T04:44:32+00:00     news
# 4       2019-09-26T04:54:03+00:00     news
# ...                           ...      ...
# 409923  2019-09-26T08:07:52+00:00     news
# 409924  2019-09-26T08:07:52+00:00     news
# 409925  2019-09-26T08:07:53+00:00     news
# 409926  2019-09-26T08:07:53+00:00     news
# 409927  2019-09-26T08:07:55+00:00     news
#
#                                                   content  \
# 0       원익IPS는 삼성전자와 40억원 규모의 반도체 제조장비 공급계약을 체결했다고 4일 ...
# 1       태블릿PC 등 신제품 수출 확대 전망\n\n 정천기 기자 = 우리나라 수출이 올해에...
# 2       삼성전자가 1차 협력사는 물론 2, 3차 협력사들까지 저리로 경영자금을 빌릴 수 있...
# 3       반도체와 액정화면(LCD) 장비기업인 참엔지니어링(구 참앤씨)은 일본 등 해외업체들...
# 4       우리나라 수출이 올해에 이어 내년 1분기에도 고공행진을 이어갈 것으로 전망됐다.\n...
# ...                                                   ...
# ...

# %%
import matplotlib.pyplot as plt 
plt.plot(data['score'])

# %%
data.describe()
# Out:
#                score           uid
# count  409928.000000  4.099280e+05
# mean       25.142448  4.062365e+17
# std        19.305877  1.316238e+17
# min         3.005598  3.172840e+17
# 25%        14.806419  3.182010e+17
# 50%        17.723497  3.226730e+17
# 75%        22.473635  4.891642e+17
# max       102.613690  7.639820e+17

# %%
del data['category']
del data['content_url']
del data['publisher']
del data['section']
del data['uid']
data
# Out:
#                        @timestamp  \
# 0       2019-09-26T05:09:04+00:00
# 1       2019-09-26T04:54:03+00:00
# 2       2019-09-26T04:48:02+00:00
# 3       2019-09-26T04:44:32+00:00
# 4       2019-09-26T04:54:03+00:00
# ...                           ...
# 409923  2019-09-26T08:07:52+00:00
# 409924  2019-09-26T08:07:52+00:00
# 409925  2019-09-26T08:07:53+00:00
# 409926  2019-09-26T08:07:53+00:00
# 409927  2019-09-26T08:07:55+00:00
#
#                                                   content  \
# 0       원익IPS는 삼성전자와 40억원 규모의 반도체 제조장비 공급계약을 체결했다고 4일 ...
# 1       태블릿PC 등 신제품 수출 확대 전망\n\n 정천기 기자 = 우리나라 수출이 올해에...
# 2       삼성전자가 1차 협력사는 물론 2, 3차 협력사들까지 저리로 경영자금을 빌릴 수 있...
# 3       반도체와 액정화면(LCD) 장비기업인 참엔지니어링(구 참앤씨)은 일본 등 해외업체들...
# 4       우리나라 수출이 올해에 이어 내년 1분기에도 고공행진을 이어갈 것으로 전망됐다.\n...
# ...                                                   ...
# 409923  산업통상자원부는 성윤모 장관이 28일(현지시간) 중국 하이난성에서 개최되는 보아오포...
# 409924  SK 하이닉스 충칭 공장도 찾아 격려\n\n 김현철 기자 = 올해 첫 순방길에 오른...
# ...

# %%
del data['@timestamp']
del data['keyword']
data
# Out:
#                                                   content  \
# 0       원익IPS는 삼성전자와 40억원 규모의 반도체 제조장비 공급계약을 체결했다고 4일 ...
# 1       태블릿PC 등 신제품 수출 확대 전망\n\n 정천기 기자 = 우리나라 수출이 올해에...
# 2       삼성전자가 1차 협력사는 물론 2, 3차 협력사들까지 저리로 경영자금을 빌릴 수 있...
# 3       반도체와 액정화면(LCD) 장비기업인 참엔지니어링(구 참앤씨)은 일본 등 해외업체들...
# 4       우리나라 수출이 올해에 이어 내년 1분기에도 고공행진을 이어갈 것으로 전망됐다.\n...
# ...                                                   ...
# 409923  산업통상자원부는 성윤모 장관이 28일(현지시간) 중국 하이난성에서 개최되는 보아오포...
# 409924  SK 하이닉스 충칭 공장도 찾아 격려\n\n 김현철 기자 = 올해 첫 순방길에 오른...
# 409925  SK하이닉스 ‘상생 지원방안’ 확정\n상생펀드3000억·AI 센터 6380억 투입 ...
# 409926  경기도교육청은 올해 1학기 경기꿈의대학이 다음 달 3일까지 강좌별 일정에 따라 개강...
# 409927  세계 최대의 반도체 수요 업체 가운데 한 곳인 미국 아마존이 삼성전자에 D램 반도체...
#
#                       created_date      score  \
# 0       2011-08-04T14:10:00.000000  77.258360
# 1       2010-12-27T11:00:00.000000  14.783678
# 2       2010-08-16T11:00:00.000000  12.695696
# 3       2010-06-14T09:13:00.000000  24.913132
# ...
